# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

survey = pd.read_excel("../research/Survey table.xlsx")
survey.head()
# Out:
#   Paper ID                                              Title    Year  \
# 0  Paper 1  A Deep Learning Approach for Helmet Detection ...  2025.0
# 1  Paper 2  An Efficient and Layout-Independent ALPR Syste...  2021.0
# 2  Paper 3  Automated Traffic Violation Detection Using AI...  2025.0
# 3  Paper 4  Automatic Traffic Rules Violation Detection an...  2020.0
# 4  Paper 5  AI-Based Integrated Traffic Violation Detectio...  2025.0
#
#                                          Methodology  \
# 0  A real-time system to detect motorcyclists wit...
# 1  End-to-end, layout-independent Automatic Licen...
# 2  A review paper outlining a general framework f...
# 3  An automated system for Bangladesh to detect r...
# 4  A comprehensive review on AI for traffic viola...
#
#                                      Algorithms Used  \
# 0  YOLOv3, OpenCV, EasyOCR/Pytesseract, Haarcasca...
# 1     Modified YOLOv2, Modified Fast-YOLOv2, CR-NET.
# 2          Reviews CNNs, YOLO, SSD, OCR, RNNs/LSTMs.
# 3                     YOLOv3, OpenCV, CNN in MATLAB.
# 4  LoLTV, GA-YOLOv5, Reinforcement Learning, Fede...
#
#                                      Dataset(s) Used  \
# 0                       COCO, Custom Kaggle dataset.
# 1  8 public datasets (AOLP, UFPR-ALPR, etc.) and ...
# 2  Discusses the need for large-scale datasets bu...
# 3  Pre-recorded video footage; YOLOv3 used defaul...
# 4  References LoLTV, AI City Challenge, Traffic4S...
#
#                                              Results  \
# 0               95.2% accuracy for helmet detection.
# 1  96.9% recognition rate; 73 FPS on a high-end GPU.
# 2  Summarizes that AI systems can achieve high ac...
# 3    >90% violation detection (day), 98% ANPR (day).
# 4  Synthesizes results: LoLTV (98.2% precision), ...
#
#                                          Limitations              Author(s)
# 0  Struggles with variable lighting, motion blur,...    Sulbha Yadav et al.
# 1  Not trained for Chinese characters; errors fro...   Rayson Laroca et al.
# 2  Field-wide issues: data privacy, poor weather ...  Angelina Grace et al.
# 3  Accuracy is significantly lower at night; sens...  Raian Shahrear et al.
# 4  Lack of Indian datasets, poor performance on e...    Avadhut Dilip sutar

# %%
plt.figure(figsize=(8,5))
survey['Year'].value_counts().sort_index().plot(kind='bar', color='skyblue')
plt.title("Number of Papers Per Year")
plt.xlabel("Year")
plt.ylabel("Count")
plt.show()

# %%
from collections import Counter

algo_list = []

for entry in survey['Algorithms Used'].dropna():
    items = entry.replace(",", " ").replace("/", " ").split()
    algo_list.extend(items)

algo_counts = Counter(algo_list)

algo_counts
# Out:
# Counter({'YOLOv3': 8,
#          'YOLOv8': 6,
#          'OCR.': 6,
#          'OpenCV': 5,
#          'CNN': 5,
#          'YOLOv5': 5,
#          'OCR': 3,
#          'Learning': 3,
#          'Tesseract': 3,
#          'R-CNN': 3,
#          'Faster': 3,
#          'EasyOCR': 2,
#          'Modified': 2,
#          'YOLOv2': 2,
#          'CNNs': 2,
#          'YOLO': 2,
#          'SSD': 2,
#          'DPM': 2,
#          'Custom': 2,
#          'Gaussian': 2,
#          'CNN.': 2,
#          'OpenCV.': 2,
#          'YOLOv7': 2,
#          'YOLOv9.': 2,
#          'Pytesseract': 1,
#          'Haarcascade': 1,
#          'classifier.': 1,
#          'Fast-YOLOv2': 1,
#          'CR-NET.': 1,
#          'Reviews': 1,
#          'RNNs': 1,
#          'LSTMs.': 1,
#          'in': 1,
#          'MATLAB.': 1,
#          'LoLTV': 1,
#          'GA-YOLOv5': 1,
#          'Reinforcement': 1,
#          'Federated': 1,
#          'Blockchain.': 1,
#          '(Single': 1,
#          'Shot': 1,
#          'Multi-Box': 1,
#          'Detector)': 1,
#          '(baseline).': 1,
#          'Deep': 1,
#          'Image': 1,
#          'Processing': 1,
#          'Ultrasonic': 1,
#          'sensors.': 1,
#          '(extra-large)': 1,
#          'low-light': 1,
#          'enhancement': 1,
#          'algorithm.': 1,
#          'strongSORT': 1,
#          'WPOD-NET': 1,
#          'MobileNet.': 1,
#          'Blur': 1,
#          'Canny': 1,
#          'Edge': 1,
#          'Detection.': 1,
#          'Darknet-53': 1,
#          'Hybrid': 1,
#          '(PaddleOCR': 1,
#          'EasyOCR)': 1,
#          'DeepSORT.': 1,
#          'Evaluates': 1,
#          'numerous': 1,
#          'combinations': 1,
#          'including': 1,
#          'GOG': 1,
#          'MHT': 1,
#          'IOU.': 1,
#          'YOLOv10': 1,
#          'DeepSORT': 1,
#          'Unspecified': 1,
#          '(Canny': 1,
#          'edge': 1,
#          'detection)': 1,
#          'Template': 1,
#          'Matching.': 1,
#          'Centroid': 1,
#          'Tracking.': 1,
#          'Optical': 1,
#          'Flow.': 1,
#          'Mixture': 1,
#          'Model': 1,
#          '(GMM)': 1,
#          'YOLOv4': 1,
#          '(color': 1,
#          'segmentation': 1,
#          'background': 1,
#          'subtraction)': 1,
#          'Improved': 1,
#          'YOLOv8n.': 1,
#          'SG-YOLOv5': 1,
#          '(incorporating': 1,
#          'ShuffleNetv2': 1,
#          'and': 1,
#          'GhostNet).': 1,
#          '(Xception': 1,
#          'Inception-ResNet': 1,
#          'v2': 1,
#          'based)': 1,
#          'Bidirectional': 1,
#          'CudnnLSTM': 1,
#          'CTC': 1,
#          'YOLOv3.': 1,
#          'R-CNN.': 1,
#          'TesseractOCR': 1,
#          'custom': 1,
#          'TensorFlow-CNN.': 1,
#          'tailored': 1,
#          'Xception': 1,
#          '2D': 1,
#          'Attention-based': 1,
#          'RNN': 1,
#          'LSTM': 1,
#          'AsymCycleGAN.': 1})

# %%
import re
from collections import Counter
ALGO_GROUPS = {
    "YOLO Family": ["yolov1", "yolov2", "yolov3", "yolov4", "yolov5", "yolov6", "yolov7", "yolov8", "yolov9"],
    "CNN Models": ["cnn", "lenet", "alexnet", "vgg", "resnet", "mobilenet", "efficientnet"],
    "Transformers": ["transformer", "vit", "vision-transformer", "swin"],
    "Tracking Models": ["deepsort", "bytetrack", "sort"],
    "OCR Models": ["easyocr", "tesseract", "crnn", "lprnet", "ctc"],
    "Classical ML / CV": ["haarcascade", "hog", "svm", "kmeans", "gmm"],
}
detected_algos = []

for text in survey["Algorithms Used"].dropna():
    t = text.lower()
    for group, keywords in ALGO_GROUPS.items():
        for kw in keywords:
            if kw in t:
                detected_algos.append(group)
algo_group_counts = Counter(detected_algos)
algo_group_counts
# Out:
# Counter({'YOLO Family': 31,
#          'CNN Models': 17,
#          'OCR Models': 9,
#          'Tracking Models': 5,
#          'Classical ML / CV': 2})

# %%
plt.figure(figsize=(10,6))
plt.bar(algo_group_counts.keys(), algo_group_counts.values(), color="blue")
plt.title("Algorithm Categories Used Across Papers")
plt.ylabel("Frequency")
plt.xticks(rotation=45)
plt.show()

# %%
yolo_versions = []

for text in survey["Algorithms Used"].dropna():
    t = text.lower()
    for version in ["yolov3", "yolov4", "yolov5", "yolov7", "yolov8"]:
        if version in t:
            yolo_versions.append(version)

Counter(yolo_versions)
# Out:
# Counter({'yolov3': 9, 'yolov5': 7, 'yolov8': 7, 'yolov7': 2, 'yolov4': 1})

# %%
from collections import Counter
import matplotlib.pyplot as plt

# Count YOLO version usage
version_counts = Counter(yolo_versions)

# Plot
plt.figure(figsize=(8,5))
plt.bar(version_counts.keys(), version_counts.values(), color="teal")

plt.title("YOLO Version Usage Across Papers", fontsize=14)
plt.xlabel("YOLO Version", fontsize=12)
plt.ylabel("Frequency", fontsize=12)
plt.xticks(rotation=0)

for i, v in enumerate(version_counts.values()):
    plt.text(i, v + 0.1, str(v), ha='center', fontsize=10)

plt.show()

# %%
top_algos = dict(algo_counts.most_common(10))

plt.figure(figsize=(10,5))
plt.bar(top_algos.keys(), top_algos.values(), color="orange")
plt.title("Top Algorithms Used in Research Papers")
plt.ylabel("Frequency")
plt.xticks(rotation=45)
plt.show()

# %%
import re
from collections import Counter

KNOWN_DATASETS = [
    "UA-DETRAC", "AOLP", "CCPD", "COCO", "MSCOCO", "UFPR-ALPR", 
    "LoLTV", "KITTI", "PKUData", "OpenALPR", "NP-ALPR", "Traffic4Safe",
    "Dhaka-AI", "Kaggle", "City", "Challenge", "Roboflow"
]

detected = []

for text in survey['Dataset(s) Used'].dropna():
    for ds in KNOWN_DATASETS:
        if ds.lower() in text.lower():
            detected.append(ds)

Counter(detected)
# Out:
# Counter({'AOLP': 3,
#          'UA-DETRAC': 3,
#          'COCO': 2,
#          'Kaggle': 2,
#          'UFPR-ALPR': 2,
#          'LoLTV': 2,
#          'CCPD': 2,
#          'OpenALPR': 1,
#          'Traffic4Safe': 1,
#          'City': 1,
#          'Challenge': 1,
#          'MSCOCO': 1,
#          'Roboflow': 1,
#          'KITTI': 1,
#          'NP-ALPR': 1,
#          'PKUData': 1})

# %%
ds_counts = Counter(detected)

plt.figure(figsize=(10,5))
plt.bar(ds_counts.keys(), ds_counts.values(), color="green")
plt.title("Frequency of Datasets Used Across Papers")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# %%
import re
from collections import Counter

# Clean, meaningful limitation keywords (custom curated)
LIMITATION_KEYWORDS = [
    "low-light", "night", "lighting", "blur", "occlusion", "motion",
    "dataset", "data", "small", "limited", "noise", "shadow",
    "overlap", "crowded", "occluded", "weather", "rain", "fog",
    "real-time", "fps", "speed", "latency", "cost", "compute",
    "infrastructure", "scalability", "resolution", "accuracy",
    "generalization", "localization", "tracking", "annotation",
    "imbalance", "noise", "domain", "transfer", "variation"
]

detected_limits = []

for text in survey['Limitations'].dropna():
    t = text.lower()
    for kw in LIMITATION_KEYWORDS:
        if kw in t:
            detected_limits.append(kw)

Counter(detected_limits)
# Out:
# Counter({'lighting': 9,
#          'blur': 7,
#          'occlusion': 7,
#          'accuracy': 5,
#          'motion': 4,
#          'shadow': 4,
#          'data': 4,
#          'weather': 4,
#          'night': 4,
#          'rain': 2,
#          'dataset': 2,
#          'crowded': 2,
#          'cost': 1,
#          'resolution': 1,
#          'variation': 1,
#          'tracking': 1,
#          'speed': 1,
#          'occluded': 1,
#          'small': 1,
#          'overlap': 1})

# %%
limit_counts = Counter(detected_limits)

plt.figure(figsize=(12,6))
plt.bar(limit_counts.keys(), limit_counts.values(), color="red")
plt.title("Most Common Research Limitations Across Papers")
plt.ylabel("Frequency")
plt.xticks(rotation=45)
plt.show()

# %%
GROUPS = {
    "Low-light / Night": ["low-light", "night", "lighting"],
    "Motion / Blur": ["blur", "motion"],
    "Occlusion": ["occlusion", "occluded", "overlap"],
    "Dataset Issues": ["dataset", "small", "limited", "imbalance"],
    "Weather": ["rain", "fog", "weather"],
    "Real-time Constraints": ["real-time", "fps", "latency"],
    "Accuracy Issues": ["accuracy", "generalization", "localization"],
    "Compute Cost": ["cost", "compute", "infrastructure"],
}

group_counts = {}

for group_name, words in GROUPS.items():
    count = sum(limit_counts[w] for w in words if w in limit_counts)
    group_counts[group_name] = count

group_counts
# Out:
# {'Low-light / Night': 13,
#  'Motion / Blur': 11,
#  'Occlusion': 9,
#  'Dataset Issues': 3,
#  'Weather': 6,
#  'Real-time Constraints': 0,
#  'Accuracy Issues': 5,
#  'Compute Cost': 1}

# %%
plt.figure(figsize=(12,6))
plt.bar(group_counts.keys(), group_counts.values(), color="purple")
plt.title("Grouped Research Limitations")
plt.ylabel("Frequency")
plt.xticks(rotation=45)
plt.show()
